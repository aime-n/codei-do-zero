# %%
import pandas as pd

df = pd.read_csv('data/tcc_ceds_music.csv')
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
#        'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy',
#        'topic', 'age'],
#       dtype='object')

# %%
df[df['artist_name'] == 'the beatles'][['topic', 'energy', 'artist_name', 'track_name']]
# Out:
#             topic    energy  artist_name                   track_name
# 23629  world/life  0.817812  the beatles            not a second time
# 23630       music  0.579566  the beatles           all i've got to do
# 23631    romantic  0.388369  the beatles  you really got a hold on me
# 23632       music  0.338318  the beatles           till there was you
# 23633    romantic  0.563550  the beatles                all my loving
# ...           ...       ...          ...                          ...
# 25093  night/time  0.770764  the beatles              long tall sally
# 25123  night/time  0.691682  the beatles             i call your name
# 25131     sadness  0.337317  the beatles                     this boy
# 25142  world/life  0.329308  the beatles                    yes it is
# 25722    feelings  0.671661  the beatles                    real love
#
# [66 rows x 4 columns]
